# %%
import tensorflow as tf

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D,Dense,Flatten,Dropout,GlobalMaxPooling2D,MaxPooling2D,BatchNormalization

# %%
# Load in the data
cifar10 = tf.keras.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
y_train, y_test = y_train.flatten(), y_test.flatten()
print("x_train.shape:", x_train.shape)
print("y_train.shape", y_train.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step
# x_train.shape: (50000, 32, 32, 3)
# y_train.shape (50000,)

# %%
# number of classes
K = len(set(y_train))
print("number of classes:", K)
# Out:
# number of classes: 10

# %%
# Build the model using the functional API
def create_model():
  i = Input(shape=x_train[0].shape)

  x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
  x = BatchNormalization()(x)
  x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
  x = BatchNormalization()(x)
  x = MaxPooling2D((2, 2))(x)
  x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
  x = BatchNormalization()(x)
  x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
  x = BatchNormalization()(x)
  x = MaxPooling2D((2, 2))(x)
  x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
  x = BatchNormalization()(x)
  x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
  x = BatchNormalization()(x)
  x = MaxPooling2D((2, 2))(x)

  x = Flatten()(x)
  x = Dropout(0.2)(x)
  x = Dense(1024, activation='relu')(x)
  x = Dropout(0.2)(x)
  x = Dense(512, activation='softmax')(x)

  model = Model(i, x)
  return model

# %%
strategy = tf.distribute.MirroredStrategy()
# strategy = tf.distribute.experimental.CentralStorageStrategy()

# %%
print(f'Number of devices: {strategy.num_replicas_in_sync}')
# Out:
# Number of devices: 1

# %%
# Critical part
with strategy.scope():
  model = create_model()
  model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

# %%
# Fit
r = model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=128, epochs=15)
# Out:
# Epoch 1/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.4362 - loss: 1.9152 - val_accuracy: 0.3807 - val_loss: 1.8283
# Epoch 2/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.6945 - loss: 0.8599 - val_accuracy: 0.7000 - val_loss: 0.8594
# Epoch 3/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.7722 - loss: 0.6451 - val_accuracy: 0.7647 - val_loss: 0.6765
# Epoch 4/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - accuracy: 0.8175 - loss: 0.5207 - val_accuracy: 0.7438 - val_loss: 0.7636
# Epoch 5/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - accuracy: 0.8551 - loss: 0.4181 - val_accuracy: 0.7910 - val_loss: 0.6355
# Epoch 6/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - accuracy: 0.8804 - loss: 0.3384 - val_accuracy: 0.7881 - val_loss: 0.7024
# Epoch 7/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - accuracy: 0.9037 - loss: 0.2716 - val_accuracy: 0.8085 - val_loss: 0.6107
# Epoch 8/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - accuracy: 0.9261 - loss: 0.2118 - val_accuracy: 0.8220 - val_loss: 0.6055
# Epoch 9/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.9340 - loss: 0.1850 - val_accuracy: 0.8171 - val_loss: 0.6315
# Epoch 10/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.9460 - loss: 0.1599 - val_accuracy: 0.8085 - val_loss: 0.6965
# Epoch 11/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.9512 - loss: 0.1376 - val_accuracy: 0.8146 - val_loss: 0.6992
# Epoch 12/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.9578 - loss: 0.1184 - val_accuracy: 0.7906 - val_loss: 0.8209
# Epoch 13/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.9621 - loss: 0.1096 - val_accuracy: 0.8096 - val_loss: 0.7659
# Epoch 14/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 0.9632 - loss: 0.1058 - val_accuracy: 0.7767 - val_loss: 1.0401
# Epoch 15/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - accuracy: 0.9660 - loss: 0.1000 - val_accuracy: 0.8110 - val_loss: 0.8597

# %%
50000/391
# Out:
# 127.8772378516624

# %%
10000/79
# Out:
# 126.58227848101266

# %%
#Compare this to non-distributed training
model2 = create_model()
model2.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
r = model2.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=128, epochs=15)
# Out:
# Epoch 1/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - accuracy: 0.4411 - loss: 1.8524 - val_accuracy: 0.3910 - val_loss: 1.9148
# Epoch 2/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.7058 - loss: 0.8356 - val_accuracy: 0.6934 - val_loss: 0.8845
# Epoch 3/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7795 - loss: 0.6248 - val_accuracy: 0.7286 - val_loss: 0.7990
# Epoch 4/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.8221 - loss: 0.5007 - val_accuracy: 0.7907 - val_loss: 0.6175
# Epoch 5/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8601 - loss: 0.3992 - val_accuracy: 0.7446 - val_loss: 0.8419
# Epoch 6/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8851 - loss: 0.3245 - val_accuracy: 0.7857 - val_loss: 0.6544
# Epoch 7/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9059 - loss: 0.2631 - val_accuracy: 0.8096 - val_loss: 0.6129
# Epoch 8/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9259 - loss: 0.2102 - val_accuracy: 0.7963 - val_loss: 0.6503
# Epoch 9/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.9354 - loss: 0.1843 - val_accuracy: 0.7992 - val_loss: 0.7292
# Epoch 10/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9465 - loss: 0.1527 - val_accuracy: 0.8011 - val_loss: 0.7619
# Epoch 11/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9521 - loss: 0.1363 - val_accuracy: 0.8081 - val_loss: 0.7184
# Epoch 12/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9603 - loss: 0.1182 - val_accuracy: 0.8148 - val_loss: 0.7608
# Epoch 13/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9631 - loss: 0.1101 - val_accuracy: 0.7972 - val_loss: 0.8348
# Epoch 14/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.9613 - loss: 0.1131 - val_accuracy: 0.8117 - val_loss: 0.8324
# Epoch 15/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9674 - loss: 0.0943 - val_accuracy: 0.8164 - val_loss: 0.7651
